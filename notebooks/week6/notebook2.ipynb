# %%
import matplotlib.pyplot as plt
import plotfancy as pf
dim1 = 6
dim2 = (3/4)*dim1
fig, dummy = pf.create_plot(size=(dim1,dim2))
dummy.set_axis_off() 
ax1 = fig.add_axes((1/(2*dim1),1/dim2,4/dim1,3/dim2))
ax1.set_xlabel(r'$f$')
ax1.set_ylabel(r'$\tilde{d}(f)$')
# Explicitly define the colorbar axis to avoid layout issues
ax2 = fig.add_axes((4/dim1+0.2,1/dim2,0.1,3/dim2))
